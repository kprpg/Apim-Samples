# %% [markdown]
# ### 🛠️ Configure Infrastructure Parameters & Create the Infrastructure
#
# Set your desired parameters for the APPGW-APIM infrastructure deployment.
#
# ❗️ **Modify entries under _User-defined parameters_**.
#
# **Note:** This infrastructure includes Application Gateway with API Management using VNet injection.

# %%
from pathlib import Path
import os
import sys

workspace_root = Path.cwd()
project_root = None
for candidate in [workspace_root, *workspace_root.parents]:
    if (candidate / 'shared' / 'python').exists():
        project_root = candidate
        break

if project_root is None:
    raise ModuleNotFoundError("Could not locate 'shared/python' from current notebook path")

shared_python_path = project_root / 'shared' / 'python'
for path_entry in (shared_python_path, project_root):
    path_value = str(path_entry)
    if path_value not in sys.path:
        sys.path.insert(0, path_value)

py_path_parts = [str(shared_python_path), str(project_root)]
existing_py_path = os.environ.get('PYTHONPATH', '')
if existing_py_path:
    py_path_parts.append(existing_py_path)
os.environ['PYTHONPATH'] = os.pathsep.join(py_path_parts)

from apimtypes import APIM_SKU, INFRASTRUCTURE, Region
from utils import InfrastructureNotebookHelper
from console import print_ok

# ------------------------------
#    USER CONFIGURATION
# ------------------------------

rg_location = Region.EAST_US_2      # Azure region for deployment
index       = 1                     # Infrastructure index (use different numbers for multiple environments)
apim_sku    = APIM_SKU.DEVELOPER    # Options: 'DEVELOPER', 'PREMIUM', 'PREMIUMV2' (VNet injection supports Developer, Premium, and PremiumV2)

# ------------------------------
#    SYSTEM CONFIGURATION
# ------------------------------

inb_helper = InfrastructureNotebookHelper(rg_location, INFRASTRUCTURE.APPGW_APIM, index, apim_sku)
inb_helper.create_infrastructure()

print_ok('All done!')
# Out:
# ℹ️ Initializing Infrastructure Notebook Helper with the following parameters: ⌚ 18:25:25.209600
#
# 👉 Location                 : eastus2
# 👉 Infrastructure           : appgw-apim
# 👉 Index                    : 1
# 👉 APIM SKU                 : Developer
#
# ⚙️ az group create --name apim-infra-appgw-apim-1 --location eastus2 --tags source=apim-sample infrastructure="appgw-apim"
#
# ✅ Resource group 'apim-infra-appgw-apim-1' created ⌚ 18:25:30.698740 :1s]
#
# ⚙️ az account show
#
# 👉 Current user             : admin@MngEnvMCAP908044.onmicrosoft.com
# 👉 Tenant ID                : 173eb3fc-9ba1-437f-99a1-89d5e53b91d1
# 👉 Subscription ID          : cbaf34df-7bb5-4fcf-bd7d-686a5f43ad31
# 👉 Subscription name        : ME-MngEnvMCAP908044-gpillai-1
#
# ⚙️ az ad signed-in-user show
#
# 👉 Current user ID          : e1e9d2a5-fbb0-4891-92a3-4903151da389
# 🚀 Starting APPGW-APIM infrastructure deployment...
#
#    This deployment requires multiple steps:
#
#    1. Create Key Vault and self-signed certificate
#    2. Deploy infrastructure (APIM in VNet Internal mode)
#
# 📋 Step 1: Creating Key Vault and certificate...
#
# Creating Key Vault: kv-u236o4j372eai
# ✅ Key Vault created: kv-u236o4j372eai ⌚ 18:26:41.424221
# ✅ Assigned Key Vault Certificates Officer role to current user ⌚ 18:26:44.846948
# ⏳ Waiting for role assignment propagation (15 seconds)...
#
# 🔐 Creating self-signed certificate in Key Vault...
#
# 👉 Key Vault                : kv-u236o4j372eai
# 👉 Certificate              : appgw-cert
# 👉 Domain                   : api.apim-samples.contoso.com
#
# ⚙️ az keyvault certificate create --vault-name kv-u236o4j372eai --name appgw-cert --policy "{\"issuerParameters\": {\"name\": \"Self\"}, \"keyProperties\": {\"exportable\": true, \"keySize\": 2048, \"keyType\":
# \"RSA\", \"reuseKey\": true}, \"secretProperties\": {\"contentType\": \"application/x-pkcs12\"}, \"x509CertificateProperties\": {\"keyUsage\": [\"digitalSignature\", \"keyEncipherment\"], \"subject\":
# \"CN=api.apim-samples.contoso.com\", \"validityInMonths\": 12}}"
#
# ✅ Certificate created successfully in Key Vault ⌚ 18:27:09.122178 :7s]
#
# ✅ Step 1: Key Vault and certificate creation completed ⌚ 18:27:09.122673
#
# 📋 Step 2: Deploying infrastructure...
#
# 🚀 Creating infrastructure...
#
# 👉 Infrastructure           : appgw-apim
# 👉 Index                    : 1
# 👉 Resource group           : apim-infra-appgw-apim-1
# 👉 Location                 : eastus2
# 👉 APIM SKU                 : Developer
#
# 📁 Changed working directory to: /workspaces/Apim-Samples/infrastructure/appgw-apim
# 📝 Updated the policy XML in the bicep parameters file 'params.json'
#
# ⚙️ az deployment group create --name appgw-apim --resource-group apim-infra-appgw-apim-1 --template-file "/workspaces/Apim-Samples/infrastructure/appgw-apim/main.bicep" --parameters
# "/workspaces/Apim-Samples/infrastructure/appgw-apim/params.json" --query "properties.outputs"

# %% [markdown]
# ### 🗑️ Clean up resources
#
# When you're finished experimenting, it's advisable to remove all associated resources from Azure to avoid unnecessary cost.
# Use the [clean-up notebook](clean-up.ipynb) for that.
