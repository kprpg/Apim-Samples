# %% [markdown]
# ### 🗑️ Clean up resources
#
# When you're finished with the lab, you should remove all your deployed resources from Azure to avoid extra charges and keep your Azure subscription uncluttered.

# %%
from apimtypes import INFRASTRUCTURE
from infrastructures import cleanup_infra_deployments

indexes = [1]

cleanup_infra_deployments(INFRASTRUCTURE.APPGW_APIM, indexes)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from apimtypes import INFRASTRUCTURE
#       2 from infrastructures import cleanup_infra_deployments
#       4 indexes = [1]
#
# ModuleNotFoundError: No module named 'apimtypes'
