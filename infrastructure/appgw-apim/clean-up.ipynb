# %% [markdown]
# ### 🗑️ Clean up resources
#
# When you're finished with the lab, you should remove all your deployed resources from Azure to avoid extra charges and keep your Azure subscription uncluttered.

# %%
from pathlib import Path
import os
import sys

workspace_root = Path.cwd()
project_root = None
for candidate in [workspace_root, *workspace_root.parents]:
    if (candidate / 'shared' / 'python').exists():
        project_root = candidate
        break

if project_root is None:
    raise ModuleNotFoundError("Could not locate 'shared/python' from current notebook path")

shared_python_path = project_root / 'shared' / 'python'
for path_entry in (shared_python_path, project_root):
    path_value = str(path_entry)
    if path_value not in sys.path:
        sys.path.insert(0, path_value)

py_path_parts = [str(shared_python_path), str(project_root)]
existing_py_path = os.environ.get('PYTHONPATH', '')
if existing_py_path:
    py_path_parts.append(existing_py_path)
os.environ['PYTHONPATH'] = os.pathsep.join(py_path_parts)

from apimtypes import INFRASTRUCTURE
from infrastructures import cleanup_infra_deployments

indexes = [1]

cleanup_infra_deployments(INFRASTRUCTURE.APPGW_APIM, indexes)
# Out:
# ℹ️ Cleaning up resources for appgw-apim - 1
# ℹ️ Resource group : apim-infra-appgw-apim-1
#
# ⚙️ az deployment group show --name appgw-apim -g apim-infra-appgw-apim-1 -o json
#
# ✅ Deployment retrieved ⌚ 20:04:33.163808 :1s]
#
# ⚙️ az cognitiveservices account list -g apim-infra-appgw-apim-1
#
# ✅ Listed CognitiveService accounts ⌚ 20:04:34.191665 :1s]
#
# ⚙️ az apim list -g apim-infra-appgw-apim-1
#
# ✅ Listed APIM resources ⌚ 20:04:35.203653 :1s]
#
# ⚙️ az keyvault list -g apim-infra-appgw-apim-1
#
# ✅ Listed Key Vault resources ⌚ 20:04:36.810338 :1s]
# ℹ️ Found 1 resource(s) to clean up. Processing in parallel...
# ℹ️ Starting parallel cleanup of 1 resource(s) with 1 worker(s)...
# ℹ️ Deleting and purging keyvault 'kv-u236o4j372eai'...
#
# ⚙️ az keyvault delete -n kv-u236o4j372eai -g apim-infra-appgw-apim-1
#
# ✅ keyvault 'kv-u236o4j372eai' deleted ⌚ 20:04:40.291975 :3s]
#
# ⚙️ az keyvault purge -n kv-u236o4j372eai --location "eastus2" --no-wait
#
# ✅ keyvault 'kv-u236o4j372eai' purged ⌚ 20:04:41.728988 :1s]
# ✅ ✓ Cleaned up keyvault 'kv-u236o4j372eai' (1/1) ⌚ 20:04:41.730354
# ✅ All 1 resource(s) cleaned up successfully! ⌚ 20:04:41.731450
# ℹ️ Deleting resource group 'apim-infra-appgw-apim-1'... ⌚ 20:04:41.732101
#
# ⚙️ az group delete --name apim-infra-appgw-apim-1 -y --no-wait
#
# ✅ Initiated deletion of resource group 'apim-infra-appgw-apim-1' ⌚ 20:04:42.825563 :1s]
# ℹ️ Cleanup completed. ⌚ 20:04:42.827968
